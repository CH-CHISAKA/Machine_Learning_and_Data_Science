# %% [markdown]
# # WEEK01: Palmer Penguins Dataset

# %% [markdown]
# | Key              | Value                                                                                                                                                                                                                                                                                                            |
# |:-----------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Week01** | Palmer Penguins                                                                                                                                                                                                                                                                                            |
# | **Course Names** | Machine Learning and Dataset                                                                                                                                                                                               |
# | **Submission Deadline**     | September 23, 2026, 10:00 PM                                                                                                                                                                                                                                                                                          |
# | **Student Name**     | Edward Chisaka                                                                                                                                                                                                                                                                                                     |
# | **Contact**      | edward.chisaka@stud.hslu.ch                                                                                                                                                                                                                                                                                           |
# | **Note**         | The link is directed to the specific GitHub file for this _Week01_ Lab implementation exercise.<br/> **_Palmer Penguins_** dataset using Python.<br/> _The goal is to get familiar with data exploration: making plots, computing statistics from the data, getting information about size of the data_. <br/> Github citation: [BibTeX]() |
